# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
file = 'lvl_candice.csv'
df = pd.read_csv(file, encoding="ISO-8859-1", parse_dates=['Date'], index_col='Date')
df.head()
# Out:
#               0BILL_TYPE___T  0FISCYEAR 0DIVISION___T Transactoin State  \
# Date
# 2015-08-05  DOMESTIC INVOICE       2015           EWP  Finished Product
# 2017-12-27  DOMESTIC INVOICE       2017           EWP  Finished Product
# 2018-02-20  DOMESTIC INVOICE       2018           EWP  Finished Product
# 2017-04-20  DOMESTIC INVOICE       2017           EWP  Finished Product
# 2017-09-06  DOMESTIC INVOICE       2017           EWP  Finished Product
#
#            Material Level 2 Material Level 3 Material Group Material Grade  \
# Date
# 2015-08-05              LVL              SLD        LV1.718           2.0E
# 2017-12-27              LVL              SLD      LV1.711.8           2.0E
# 2018-02-20              LVL              SLD      LV1.711.8           2.0E
# 2017-04-20              LVL              SLD      LV1.711.8           2.0E
# 2017-09-06              LVL              SLD        LV1.716           2.0E
#
# ...

# %%
df = df.drop(columns=['Qty_in_Conv_Vol','Fiscal_Year_Period_Text','Cal_Quarter_text', 'Ship To Region', 'Ship To Country','Plant Nbr', 'Ship To City', 'Ship To County','0DIVISION___T', 'Transactoin State',
        'Material Level 3', 'Material Group','Material Grade','0BILL_TYPE___T'])

# %%
nineteen_df = df.loc[df['0FISCYEAR']==2019]

# %%
nineteen_df = nineteen_df.drop(columns=['0FISCYEAR','Product ID'])
nineteen_df.to_csv('2019')

# %%
eighteen_df = df.loc[df['0FISCYEAR']==2018]
eighteen_df.to_csv('2018')

# %%
seventeen_df = df.loc[df['0FISCYEAR']==2017]
seventeen_df.to_csv('2017')

# %%
sixteen_df = df.loc[df['0FISCYEAR']==2016]
sixteen_df.to_csv('2016')

# %%
fifteen_df = df.loc[df['0FISCYEAR']==2015]
fifteen_df.to_csv('2015')

# %%
fourteen_df = df.loc[df['0FISCYEAR']==2014]
fourteen_df.to_csv('2014')

# %%
twenty_df = df.loc[df['0FISCYEAR']==2020]
twenty_df.to_csv('2020')
